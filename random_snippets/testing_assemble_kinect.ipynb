# %%
import rospyfrom sensor_msgs.msg import Image, CameraInfo, PointCloud2from shared_autonomy_msgs.srv import *

# %%
# Tully indicated that this should work in the new common_msgs release (1.9.17)from sensor_msgs import point_cloud2
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /home/lil1pal/catkin_ws/src/shared_autonomy/random_snippets/<ipython-input-22-566428014f32> in <module>()
#       1 # Tully indicated that this should work in the new common_msgs release (1.9.17)
#
# ----> 2 from sensor_msgs import point_cloud2
#
# ImportError: cannot import name point_cloud2

# %%
ka = rospy.ServiceProxy('assemble_kinect', KinectAssembly)

# %%
resp = ka()

# %%
gen = read_points(resp.points)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/lil1pal/catkin_ws/src/shared_autonomy/random_snippets/<ipython-input-4-86a956a2648f> in <module>()
# ----> 1 gen = read_points(resp.points)
#
# NameError: name 'read_points' is not defined

# %%
# Hmm...this saves as the text format. # http://gazebosim.org/wiki/Tutorials/CloudSim/notebook_camcorder# suggests that something similar *should* work.with open('./depth.jpg', 'w') as fp:    fp.write(resp.depth.data)with open('./image.jpg', 'w') as fp:    fp.write(resp.image.data)

# %%
import matplotlib

# %%
import sysimport rospyimport cvfrom cv_bridge import CvBridge, CvBridgeError

# %%
bridge = CvBridge()

# %%
img = bridge.imgmsg_to_cv(resp.image)depth = bridge.imgmsg_to_cv(resp.depth)

# %%
imshow(img)

# %%
imshow(depth)

# %%
print resp.image.header
# Out:
# seq: 50816stamp:   secs: 1380214591  nsecs: 47208489frame_id: /camera_rgb_optical_frame

# %%
print resp.depth.header
# Out:
# seq: 50768stamp:   secs: 1380214591  nsecs: 30210640frame_id: /camera_rgb_optical_frame

# %%
print resp.points.header
# Out:
# seq: 50165stamp:   secs: 1380214591  nsecs: 30210640frame_id: /camera_rgb_optical_frame
